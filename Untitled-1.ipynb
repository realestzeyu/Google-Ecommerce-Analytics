# %% [markdown]
# # Problem Statement:
# # **Does paid advertising clicks cause higher/lower conversion than organic visits?**
#
# ---

# %% [markdown]
# # Simple data cleaning
# This section only has data cleaning steps. Its quite boring, so you can just skip if you want.
#
# The analysis is on the next section!

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from io import StringIO
# %cd C:/Users/neyma/OneDrive/Desktop/work/Project/Google Analytics
# Out:
# C:\Users\neyma\OneDrive\Desktop\work\Project\Google Analytics
# C:\Users\neyma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
data = pd.read_csv("GoogleEcommerceData.csv")
data.info()
# Out:
# C:\Users\neyma\AppData\Local\Temp\ipykernel_19296\3705893820.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("GoogleEcommerceData.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   fullVisitorId   500000 non-null  object
#  1   visitId         500000 non-null  int64
#  2   medium          500000 non-null  object
#  3   source          500000 non-null  object
#  4   campaign        500000 non-null  object
#  5   deviceCategory  500000 non-null  object
#  6   country         500000 non-null  object
#  7   city            500000 non-null  object
#  8   pageviews       499948 non-null  float64
#  9   timeOnSite      251011 non-null  float64
#  10  bounces         248352 non-null  float64
#  11  revenue         500000 non-null  float64
#  12  converted       500000 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 49.6+ MB

# %%
data.head(10)
data.nunique()
# Out:
# fullVisitorId     425971
# visitId           490541
# medium                 7
# source               234
# campaign               8
# deviceCategory         3
# country              217
# city                 537
# pageviews            185
# timeOnSite          3725
# bounces                1
# revenue             3514
# converted              2
# dtype: int64

# %%
# understanding the dataset, what values it gives
for col in data.columns:
    print(f"data type is {data[col].dtype} -- AND -- the unique values within {col} are:")
    if col == 'fullVisitorId' or col == 'visitId' or col == 'timeOnSite':
        print("too many to give")
    else:
        print(data[col].unique())
    print()
# Out:
# data type is object -- AND -- the unique values within fullVisitorId are:
# too many to give
#
# data type is int64 -- AND -- the unique values within visitId are:
# too many to give
#
# data type is object -- AND -- the unique values within medium are:
# ['organic' '(none)' 'referral' 'affiliate' 'cpc' 'cpm' '(not set)']
#
# data type is object -- AND -- the unique values within source are:
# ['google' '(direct)' 'youtube.com' 'facebook.com' 'Partners' 'google.com'
#  'qiita.com' 'analytics.google.com' 'sites.google.com' 'quora.com' 'baidu'
#  'm.facebook.com' 'wheretoget.it' 'dealspotr.com' 'dfa'
#  'siliconvalley.about.com' 'phandroid.com' 'reddit.com'
#  'productforums.google.com' 'm.baidu.com' 'yahoo' 'baidu.com'
#  'mail.google.com' 'l.facebook.com' 'pinterest.com' 'bing'
#  'support.google.com' 'outlook.live.com' 'lm.facebook.com' 'ask'
#  'blog.golang.org' 'google.co.jp' 'gophergala.com' 'plus.google.com'
#  'l.messenger.com' 'docs.google.com' 'groups.google.com' 'm.yz.sm.cn'
#  'es.search.yahoo.com' 'duckduckgo.com' 'github.com' 'sashihara.jp'
#  'google.co.uk' 'uk.search.yahoo.com' 'lunametrics.com'
#  'googleads.g.doubleclick.net' 'int.search.tb.ask.com' 'm.youtube.com'
#  'cv.il3.ub.edu' 'optimize.google.com' 'images.google' 'linkedin.com'
#  'mg.mail.yahoo.com' 't.co' 'keep.google.com' 'google.se'
#  'connect.googleforwork.com' 'kr.pinterest.com' 'm.vk.com' 'wap.sogou.com'
#  'google.it' 'google.de' 'kidrex.org' 'businessinsider.com'
#  'google.com.ua' 'course.fso.fullsail.edu' 'search.mysearch.com'
#  'adwords.google.com' '(not set)' 'msn.com' 'apis.mail.yahoo.com'
#  'search.tb.ask.com' 'gatewaycdi.com' 'plus.url.google.com' 'google.co.nz'
#  'hangouts.google.com' 'it-mg42.mail.yahoo.com' 'localhost' 'intranet'
#  'new.vk.com' 'images.google.ie' 'google.com.au' 'ps-dm.reddit.com'
#  'search.xfinity.com' 'evernote.com' 'google.cz' 'm.reddit.com'
#  'learn.colorado.edu' 'flipboard.com' 's0.2mdn.net' 'seroundtable.com'
#  'squishable.com' 'google.co.in' 'google.ca' 'google.ch' 'feedly.com'
#  'messenger.com' 'lnkd.in' 'vk.com' 'in.search.yahoo.com'
#  'us.search.yahoo.com' 'm.sogou.com' 'startpage.com' 'kik.com'
#  'trainup.withgoogle.com' 'google.es' 'web.mail.comcast.net'
#  'csfirst.withgoogle.com' 'myactivity.google.com' 'br.search.yahoo.com'
#  'bing.com' 'searchlock.com' 'm.mg.mail.yahoo.com' 'google.ru'
#  'away.vk.com' 'go.mail.ru' 'nordic.businessinsider.com'
#  'learn.temple.edu' 'uk.businessinsider.com' 'ph.search.yahoo.com'
#  'images.google.de' 'amazon.com' 'tw.search.yahoo.com'
#  'se.yhs4.search.yahoo.com' 'arstechnica.com' 'ad.doubleclick.net'
#  'fr.search.yahoo.com' 'google.co.kr' 'google.com.co' 'google.com.sg'
#  'datastudio.google.com' 'getiriver.com' 'se.search.yahoo.com'
#  'google.co.th' 'so.com' 'online-metrics.com' 'google.ro' 'google.com.br'
#  'tumblr.com' 'images.google.fr' 'google.nl' 'ca.search.yahoo.com'
#  'google.fr' 'google.cl' 'earth.google.com' 'aol' 'marketingland.com'
#  'twitter.com' 'it.search.yahoo.com' 'mail.aol.com' 'id.search.yahoo.com'
#  'google.com.mx' 'web.telegram.org' 'search.incredibar.com'
#  'search.myway.com' 'suche.t-online.de' 'search.snapdo.com' 'msn'
#  'us.yhs4.search.yahoo.com' 'start.wow.com' 'mx.search.yahoo.com'
#  'malaysia.search.yahoo.com' 'de.pinterest.com' 'google.com.tw'
#  'google.com.hk' 'voice.google.com' 'us-mg5.mail.yahoo.com' 'mysearch.com'
#  'digg.com' 'spaces.google.com' 'h.yandex-team.ru'
#  'maktoob.search.yahoo.com' 'centrum.cz' 'newclasses.nyu.edu'
#  'search.earthlink.net' 'drawnames.com' 'google.gr' 'mobile.facebook.com'
#  'aulagrado.esic.edu' 'blognone.com' 'ixquick.com' 'google.co.za'
#  'markets.businessinsider.com' 'amp.reddit.com'
#  'hosted.verticalresponse.com' 'google.com.ph' 'search.1and1.com'
#  'google.co.id' 'getpocket.com' 'au.search.yahoo.com' 'google.be'
#  'en.wikipedia.org' 'us.wow.com' 'lmgtfy.com' 'prod.facebook.com'
#  'images.google.lt' 'desktop.google.com.ua' 'dena-design.qiita.com'
#  'calendar.google.com' 'cse.google.com' 'goto.google.com'
#  'chat.google.com' 'col128.mail.live.com' 'inbox.google.com' 'yandex'
#  'mail.verizon.com' 'dailydot.com' 'blackboard.towson.edu'
#  'moodle.aurora.edu' 's7-eu4.ixquick.com' 'web.facebook.com'
#  'web.whatsapp.com' 'web.skype.com' 'meetup.com' 'ex.fit.edu' 'google.bg'
#  'news.ycombinator.com' 'gsuite.google.com'
#  'staging.talkgadget.google.com' 'search.pch.com'
#  'collaborate.northwestern.edu' 'members.s7.exacttarget.com' 'm.sp.sm.cn'
#  'google.com.ar' 'google.sk' 'business.facebook.com' 'online.fullsail.edu'
#  'images.google.lk' 'basecamp.com' 'google.com.pe' 'google.co.il'
#  'wanelo.com' 'nl.yhs4.search.yahoo.com' 'google.com.pk']
#
# data type is object -- AND -- the unique values within campaign are:
# ['(not set)' 'Data Share Promo' 'AW - Dynamic Search Ads Whole Site'
#  'AW - Electronics' 'AW - Accessories' 'AW - Apparel' 'All Products'
#  'Data Share']
#
# data type is object -- AND -- the unique values within deviceCategory are:
# ['desktop' 'mobile' 'tablet']
#
# data type is object -- AND -- the unique values within country are:
# ['United States' 'India' 'South Africa' 'Canada' 'Switzerland' 'Indonesia'
#  'France' 'Spain' 'Italy' 'Brazil' 'Taiwan' 'Japan' 'Argentina'
#  'United Kingdom' 'Poland' 'Belgium' 'Thailand' 'Germany' 'Czechia'
#  'Costa Rica' 'Peru' 'Vietnam' 'Venezuela' 'Netherlands' 'Portugal'
#  'Bulgaria' 'Norway' 'Ireland' 'Malaysia' 'Turkey' 'Australia' 'Sri Lanka'
#  'Philippines' 'Pakistan' 'Mexico' 'Serbia' 'Uganda' 'Macedonia (FYROM)'
#  'Tanzania' 'Luxembourg' 'Bosnia & Herzegovina' 'Dominican Republic'
#  'El Salvador' 'Algeria' 'Kenya' 'Tunisia' 'Romania' 'Saudi Arabia'
#  'Montenegro' 'China' 'Denmark' 'Nigeria' 'Colombia' 'Israel' 'Armenia'
#  'Russia' 'Egypt' 'Uruguay' 'Hong Kong' 'South Korea' 'Morocco' 'Croatia'
#  'Slovakia' 'Slovenia' 'Greece' 'Sweden' 'Myanmar (Burma)' '(not set)'
#  'Kazakhstan' 'Ecuador' 'Chile' 'Estonia' 'Singapore' 'New Zealand'
#  'Bahrain' 'Cambodia' 'Hungary' 'Qatar' 'Paraguay' 'United Arab Emirates'
#  'Bangladesh' 'American Samoa' 'Bermuda' 'Lebanon' 'Lithuania' 'Kosovo'
#  'Albania' 'Ghana' 'Mongolia' 'Ukraine' 'Austria' 'Cyprus' 'Jordan'
#  'Belize' 'Bolivia' 'Senegal' 'Belarus' 'Georgia' 'Azerbaijan'
#  'Kyrgyzstan' 'Panama' 'Puerto Rico' 'Malta' 'Latvia' 'Macau' 'Uzbekistan'
#  'Angola' 'Cameroon' 'Iraq' 'Finland' 'Palestine' 'Jamaica' 'Zambia'
#  'Kuwait' 'Côte d’Ivoire' 'Guinea' 'Madagascar' 'Liberia' 'Jersey'
#  'Ethiopia' 'Nicaragua' 'Burkina Faso' 'Nepal' 'Benin' 'Oman' 'Aruba'
#  'Andorra' 'Martinique' 'Guatemala' 'Moldova' 'Yemen' 'Sudan' 'Iceland'
#  'Congo - Kinshasa' 'Honduras' 'Barbados' 'Trinidad & Tobago' 'Namibia'
#  'Afghanistan' 'St. Vincent & Grenadines' 'Gambia' 'Libya' 'Guam'
#  'Réunion' 'Mozambique' 'Suriname' 'Laos' 'Curaçao' 'Zimbabwe' 'Haiti'
#  'Seychelles' 'Somalia' 'Guadeloupe' 'Tajikistan' 'Grenada' 'Chad' 'Mali'
#  'Iran' 'Burundi' 'British Virgin Islands' 'Gabon' 'Mauritania'
#  'Mauritius' 'Gibraltar' 'Togo' 'Rwanda' 'Central African Republic'
#  'French Polynesia' 'Guyana' 'Turks & Caicos Islands' 'Faroe Islands'
#  'Cook Islands' 'Maldives' 'Sierra Leone' 'Cape Verde' 'Djibouti'
#  'St. Lucia' 'Syria' 'Guernsey' 'Bhutan' 'Lesotho' 'Brunei' 'Fiji'
#  'Equatorial Guinea' 'Botswana' 'French Guiana' 'U.S. Virgin Islands'
#  'Swaziland' 'Mayotte' 'Niger' 'New Caledonia' 'Greenland' 'Eritrea'
#  'San Marino' 'Congo - Brazzaville' 'Papua New Guinea' 'Bahamas' 'Vanuatu'
#  'Northern Mariana Islands' 'Monaco' 'Turkmenistan' 'Norfolk Island'
#  'Antigua & Barbuda' 'Malawi' 'Caribbean Netherlands' 'St. Kitts & Nevis'
#  'Liechtenstein' 'Isle of Man' 'St. Barthélemy' 'Cayman Islands'
#  'Marshall Islands' 'St. Pierre & Miquelon' 'Sint Maarten' 'Comoros'
#  'Dominica' 'Timor-Leste' 'Guinea-Bissau']
#
# data type is object -- AND -- the unique values within city are:
# ['not available in demo dataset' 'Portland' 'Santa Clara' 'New York'
#  'San Francisco' 'Naples' 'Sao Paulo' 'Sunnyvale' 'Seattle' 'London'
#  'Warsaw' 'Mountain View' 'Toronto' 'Austin' 'San Antonio' '(not set)'
#  'New Delhi' 'Chicago' 'Hyderabad' 'Los Angeles' 'Dublin' 'Mumbai'
#  'Sydney' 'San Jose' 'Ashburn' 'Ho Chi Minh City' 'Quezon City' 'Skopje'
#  'Mexico City' 'Izmir' 'Hanoi' 'La Victoria' 'Ankara' 'Bangkok' 'Istanbul'
#  'Lagos' 'Boardman' 'Singapore' 'Melbourne' 'Kiev' 'Minato'
#  'Tel Aviv-Yafo' 'Hong Kong' 'Bogota' 'Chandigarh' 'Osaka' 'Phoenix'
#  'Chennai' 'Kuala Lumpur' 'Paris' 'Bengaluru' 'Jakarta' 'Alexandria'
#  'Ningbo' 'Kolkata' 'Buenos Aires' 'Rome' 'Palo Alto' 'Maracaibo'
#  'Fremont' 'San Bruno' 'Dallas' 'Ann Arbor' 'Cupertino' 'Gurgaon' 'Zurich'
#  'San Mateo' 'Houston' 'Pune' 'Berlin' 'Brisbane' 'Seoul' 'Auckland'
#  'Moscow' 'Madrid' 'Munich' 'Cambridge' 'Kirkland' 'Lake Oswego'
#  'Philadelphia' 'Pittsburgh' 'Boulder' 'Salem' 'San Diego' 'Redmond'
#  'Atlanta' 'Glasgow' 'Boston' 'Jaipur' 'Montreal' 'Barcelona' 'Naha'
#  'Kochi' 'Oakland' 'Jeddah' 'Poznan' 'Prague' 'Nashville' 'Irvine'
#  'Charlotte' 'Zaragoza' 'Amsterdam' 'Santiago' 'Colombo' 'Medan'
#  'Eau Claire' 'Milan' 'Wollongong' 'Thai Nguyen' 'Stockholm' 'Columbus'
#  'Athens' 'Subang Jaya' 'Santiago de Surco' 'Shanghai' 'Oshkosh'
#  'Bien Hoa' 'Deep River' 'Washington' 'Yokohama' 'Riyadh' 'Dubai'
#  'Shinjuku' 'Ahmedabad' 'Rishon LeTsiyon' 'Beirut' 'Manila' 'Bucharest'
#  'Abu Dhabi' 'Petaling Jaya' 'Tunis' 'Nakhon Pathom'
#  'Mueang Chiang Mai District' 'Mueang Khon Kaen District' 'Can Tho' 'Vinh'
#  'Dalat' 'Da Nang' 'Hai Duong' 'Buon Ma Thuot' 'Hai Phong' 'Hue'
#  'Vung Tau' 'Rach Gia' 'Thanh Hoa' 'Cebu City' 'Karachi' 'Cork' 'Surabaya'
#  'Monterrey' 'Samsun' 'Konya' 'Mersin' 'Brasilia' 'Leon' 'Lahore' 'Vienna'
#  'Cairo' 'Belgrade' 'Baku' 'Phan Thiet' 'Hoi An' 'Nam Djinh' 'Nha Trang'
#  'Vannes' 'Montreuil' 'Rio de Janeiro' 'Council Bluffs' 'Riverside'
#  'Denver' 'Bursa' 'Antalya' 'Goiania' 'Belo Horizonte' 'Orlando'
#  'Budapest' 'Vancouver' 'Ottawa' 'Lyon' 'Adelaide' 'Redwood City'
#  'Waterloo' 'Sharjah' 'Neipu Township' 'Pryor' 'Calgary' 'Liverpool'
#  'Saint Polten' 'Zaventem' 'Kitchener' 'Utrecht' 'Adana' 'Thessaloniki'
#  'Casablanca' 'Cluj-Napoca' 'Tbilisi' 'Bandung' 'Kalamazoo' 'McAllen'
#  'Oneonta' 'Evanston' 'Lille' 'Appleton' 'Kharagpur' 'Perth' 'Lenoir'
#  'Brno' 'Minneapolis' 'San Marcos' 'Milpitas' 'Riga' 'Odessa' 'Kharkiv'
#  'Makati' 'Doha' 'Sofia' 'Nairobi' 'Davao City' 'Saint Petersburg'
#  'Sapporo' 'Krakow' 'Shibuya' 'Culpeper' 'Geneva' 'Amã' 'Curitiba'
#  'Zhongli District' 'Louisville' 'Kyiv' 'Padua' 'Detroit' 'Beijing'
#  'Guangzhou' 'Cape Town' 'Hamburg' 'Lausanne' 'Zapopan' 'Bothell'
#  'Nuremberg' 'Frankfurt' 'Greer' 'South San Francisco' 'Tucson' 'El Paso'
#  'Kansas City' 'Tigard' 'Indore' 'Bellingham' 'Taguig' 'Erode' 'Hua Hin'
#  'Campinas' 'Kampar' 'Tampa' 'Sant Cugat del Valles' 'Salford'
#  'Chevilly Larue' 'Pozuelo de Alarcon' 'Quebec City' 'Randburg' 'Lucknow'
#  'Piscataway Township' 'Lisbon' 'Gothenburg' 'Zagreb' 'Furth' 'Ridgewood'
#  'La Chorrera' 'Pescara' 'Jersey City' 'Chico' 'Sacramento' 'Odense'
#  'North Attleborough' 'Medellin' 'Wellington' 'Bilbao' 'Mississauga'
#  'Brussels' 'Lewisville' 'North Richland Hills' 'Raleigh'
#  'Issy-les-Moulineaux' 'Malaga' 'Overland Park' 'Bournemouth' 'Chuo'
#  'Lawrence Township' 'Mechelen' 'Wellesley' 'Tempe' 'Santa Fe' 'Oxford'
#  'Leuven' 'Almaty' 'Mueang Nakhon Ratchasima District' 'Aydin' 'Rockwood'
#  'Miami' 'Nottingham' 'Edmonton' 'Akron' 'Manchester' 'Birmingham'
#  'Leusden' 'Timisoara' 'My Tho' 'Eskisehir' 'Roskilde' 'Nice' 'Pleasanton'
#  'Copenhagen' 'Daegu' 'Menlo Park' 'Mueang Songkhla District' 'Qui Nhon'
#  'Seclin' 'Tallahassee' 'Wroclaw' 'Vincennes' 'Cyberjaya' 'Bordeaux'
#  'Nagoya' 'Okemos' 'Dnipro' 'Charlottesville' 'Patna' 'Cincinnati'
#  'Zaoqiao Township' 'Indianapolis' 'Canterbury' 'Almeria' 'Smyrna'
#  'Bhubaneswar' 'Dahlonega' 'Anaheim' 'Vilnius' 'Plano' 'Schagen'
#  'Bellevue' 'Noida' 'Danville' 'Barranquilla' 'Farmington Hills'
#  'Honolulu' 'Amberg' 'Iasi' 'Bekasi' 'Porto Alegre' 'Kayseri'
#  'Navi Mumbai' 'Cancun' 'College Park' 'Omaha' 'Valencia' 'Camden'
#  'Culiacan' 'Syracuse' 'Leeds' 'Goose Creek' 'Dundalk' 'Tirana'
#  'Villafranca del Castillo' 'Sherbrooke' 'Bozeman' 'Guwahati' 'Berkeley'
#  'Minxiong Township' 'Bristol' 'Hermosillo' 'Norfolk' 'Oude Meer'
#  'Chambery' 'Johnson City' 'Oviedo' 'Islamabad' 'Johor Bahru' 'Nanded'
#  'Bologna' 'Marseille' 'Coimbatore' 'Courbevoie' 'Stanford' 'Seongnam-si'
#  'Richardson' 'Las Vegas' 'Szczecin' 'The Hague' 'Groningen' 'Ipoh'
#  'Walnut Creek' 'Minsk' 'Sakai' 'Jacksonville' 'Sandy' 'Thornton'
#  'Cao Lanh' 'Netanya' 'Bratislava' 'Manaus' 'Koszalin' 'Druid Hills'
#  'Florianopolis' 'Chiyoda' 'Tampere' 'Rotterdam' 'Thai Binh' 'Arequipa'
#  'Tijuana' 'Atwater' 'Fresno' 'Herzliya' 'Phnom Penh' 'Prato'
#  'Zhudong Township' 'Oslo' 'Tallinn' 'Salt Lake City' 'Vadodara' 'Ha Tinh'
#  'Fortaleza' 'Semarang' 'Birkenes' 'Montevideo' 'LaFayette' 'Rexburg'
#  'Elche' 'Alicante' 'Breda' 'Cologne' 'Toledo' 'Sandton' 'Sibiu'
#  'Salvador' 'San Carlos' 'Ramat Gan' 'Granada' 'Eindhoven' 'East Lansing'
#  'Lincoln' 'Olomouc' 'Towson' 'Molesey' 'Longtan District' 'Greve Strand'
#  'Vladimir' 'Nea Erythraia' 'Saratoga' 'Aberdeen' 'Kovrov' 'Westville'
#  'Deva' 'Kiryat Ono' 'Whitewater' 'Mar del Plata' 'Seville' 'Panama City'
#  'Helsinki' 'Viby' 'Frederiksberg' 'Cuiaba' 'Bellflower' 'Greystones'
#  'Westlake Village' 'Turin' "'s Hertogenbosch" 'Guadalajara' 'Katowice'
#  'St. Louis' 'Avon' 'Burnaby' 'Kortrijk' 'Hamden' 'Newtonville' 'Trabzon'
#  'Saint Paul' 'Cabimas' 'South El Monte' 'Madison' 'Memphis' 'Spaichingen'
#  'Ljubljana' 'Coffeyville' 'Rosario' 'Clermont-Ferrand' 'Coventry'
#  'Aalborg' 'Woodbridge Township' 'Chino' 'Brookline' 'Salzburg'
#  "Saint-Ouen-l'Aumone" 'Ciudad Real' 'Dhaka' 'Allendale Charter Township'
#  'Byron' 'Mankato' 'Villanova' 'Chamblee' 'Osijek' 'Brampton' 'Gijon'
#  'Lehi' 'Caracas' 'Quimper' 'Hukou Township' 'Fort Worth'
#  'Parsippany-Troy Hills' 'Montigny-le-Bretonneux' 'Guatemala City'
#  'Antwerp' 'Aalen' 'Bruges' 'Los Gatos' 'Campbell' 'Belagavi' 'Hayward'
#  'Pueblo' 'Nagano' 'Annecy-le-Vieux' 'Ribeirao Preto' 'Fareham' 'Orem'
#  'Dusseldorf' 'Sabadell' 'Muntinlupa' 'University Park' 'Brest' 'Piura'
#  'Faisalabad' 'Pleiku' 'Union City' 'Targu Mures' 'Stuttgart'
#  'Santa Monica' 'New Orleans' 'Barrie']
#
# data type is float64 -- AND -- the unique values within pageviews are:
# [ 13.  12.  15.  10.   9.  11.  18.  14.  16.  22.  17.  21.  19.  26.
#   24.  28.  20.  25.  27.  29.  33.  30.  32.  31.  34.  37.  36.  40.
#    7.  42.  35.  38.  45.  47.  39.  43.  48.  44.  46.  58.  57.  68.
#   65.  73.  70.  75.  85. 104. 138.   2.   1.   3.   4.   5.   6.   8.
#   23.  52.  nan  41.  50.  49.  55.  61.  64. 122.  53.  54.  67.  56.
#   96. 100.  89.  97. 129.  51.  62. 112.  82.  69.  86. 202.  59.  76.
#   78.  80. 114. 118. 134. 167.  60.  66.  94. 132.  63.  71.  72.  99.
#  131. 109.  79.  74.  88.  95. 116. 146.  77.  92. 127. 110.  83.  90.
#   93. 176. 210. 105. 149.  84.  81. 343. 123. 195. 113.  98.  87. 120.
#  208. 183. 139. 119.  91. 143. 106. 107. 128. 324. 197. 121. 140. 102.
#  117. 124. 169. 186. 111. 165. 179. 305. 115. 125. 249. 164. 175. 327.
#  101. 126. 245. 153. 185. 188. 108. 182. 358. 466. 224. 215. 161. 156.
#  193. 135. 147. 154. 219. 270. 191. 323. 431. 351. 232. 136. 309. 341.
#  137. 469. 103. 233.]
#
# data type is float64 -- AND -- the unique values within timeOnSite are:
# too many to give
#
# data type is float64 -- AND -- the unique values within bounces are:
# [nan  1.]
#
# data type is float64 -- AND -- the unique values within revenue are:
# [  0.    97.05 178.64 ... 639.75 322.66 130.93]
#
# data type is int64 -- AND -- the unique values within converted are:
# [0 1]

# %% [markdown]
# ### Weird data values:
# From examining the values of each column, we realise that there are some interesting values, namely:
# - medium
#     - `(none)` = Direct traffic (bookmarks/typed URLs)
#     - `(not set)` = Missing tracking data
# - source
#     - `(direct)` = If medium is `(none)`
#     - `(not set)` = Unknown referral source
# - campaign
#     - `(not set)` = No campaign tags
# - Country  & city
#     - `(not set)` = Couldn't locate the location
#
# ### Most importantly, we see that these data are DIFFERENT FROM NA values, because example: `(none)` or `(not set)` HAVE MEANINGS ENCODED!! SO WE DO NOT "CLEAN" them as they are still useful interpretations from it

# %%
types_of_data = {}
# lets see what are the different data types in each columns
for col in data.columns:
    if data[col].dtype in types_of_data:
        types_of_data[data[col].dtype].append(col)
    else:    
        types_of_data[data[col].dtype] = [col]

types_of_data
# Out:
# {dtype('O'): ['fullVisitorId',
#   'medium',
#   'source',
#   'campaign',
#   'deviceCategory',
#   'country',
#   'city'],
#  dtype('int64'): ['visitId', 'converted'],
#  dtype('float64'): ['pageviews', 'timeOnSite', 'bounces', 'revenue']}

# %% [markdown]
# Obj data type O could very possibly mena that there are NULL values within the dataset. I shall nuke the whole dataset

# %%
for key, value in types_of_data.items():
    # if key == np.object_:
        for col in value:
            print(f"Column: {col}")
            print("NA SUM:", data[col].isna().sum())
            print('none SUM:', (data[col] ==  "(none)").sum())
            print('not set SUM:', (data[col] ==  "(not set)").sum())
            print()
# Out:
# Column: fullVisitorId
# NA SUM: 0
# none SUM: 0
# not set SUM: 0
#
# Column: medium
# NA SUM: 0
# none SUM: 204420
# not set SUM: 79
#
# Column: source
# NA SUM: 0
# none SUM: 0
# not set SUM: 46
#
# Column: campaign
# NA SUM: 0
# none SUM: 0
# not set SUM: 484155
#
# Column: deviceCategory
# NA SUM: 0
# none SUM: 0
# not set SUM: 0
#
# Column: country
# NA SUM: 0
# none SUM: 0
# not set SUM: 854
#
# Column: city
# NA SUM: 0
# none SUM: 0
# not set SUM: 19247
#
# Column: visitId
# NA SUM: 0
# none SUM: 0
# not set SUM: 0
#
# Column: converted
# NA SUM: 0
# none SUM: 0
# not set SUM: 0
#
# Column: pageviews
# NA SUM: 52
# none SUM: 0
# not set SUM: 0
#
# Column: timeOnSite
# NA SUM: 248989
# none SUM: 0
# not set SUM: 0
#
# Column: bounces
# NA SUM: 251648
# none SUM: 0
# not set SUM: 0
#
# Column: revenue
# NA SUM: 0
# none SUM: 0
# not set SUM: 0

# %% [markdown]
# ### NA removal?
# Seems that the only meaningful NA removalable column is `pageviews`. `timeOnSite` and `bounces` have far too many NAs to nuke, which would literally half the dataset to play with.
# - `bounces` should have NA values replaced with 0, because it implies that the user DID NOT bounce, so we should use `fillna(0)` method to indicate that they did not bounce.

# %%
# there are quite a few object types, very vague so we shall take a look deeper, into what combinations there are
for key, value in types_of_data.items():
    if key == np.object_:
        for col in value:
            print(f"Column: {col}")
            print(data[col].apply(type).value_counts())
            print()
# Out:
# Column: fullVisitorId
# fullVisitorId
# <class 'int'>    393216
# <class 'str'>    106784
# Name: count, dtype: int64
#
# Column: medium
# medium
# <class 'str'>    500000
# Name: count, dtype: int64
#
# Column: source
# source
# <class 'str'>    500000
# Name: count, dtype: int64
#
# Column: campaign
# campaign
# <class 'str'>    500000
# Name: count, dtype: int64
#
# Column: deviceCategory
# deviceCategory
# <class 'str'>    500000
# Name: count, dtype: int64
#
# Column: country
# country
# <class 'str'>    500000
# Name: count, dtype: int64
#
# Column: city
# city
# <class 'str'>    500000
# Name: count, dtype: int64

# %% [markdown]
# So medium, source, campaign, deviceCategory and country are convertable to strings

# %%
str_cols = ['medium', 'source', 'campaign', 'deviceCategory', 'country', 'city', 'fullVisitorId']
# convert object columns to string type
for col in str_cols:
    data[col] = data[col].astype(str)

data['medium'] = data['medium'].str.strip().str.lower()
data['bounces'] = data['bounces'].fillna(0).astype(int)

# Check unique values again
print(data['medium'].unique())
# Out:
# ['organic' '(none)' 'referral' 'affiliate' 'cpc' 'cpm' '(not set)']

# %%
conv = data['converted'] == 1
notconv = data['converted'] == 0
print('converted SUM:', (conv).sum())
print('converted SUM:', (notconv).sum())
print('Conversion ratio:', (conv).sum()*100/((notconv).sum()+(conv).sum()), "%")
# Out:
# converted SUM: 6622
# converted SUM: 493378
# Conversion ratio: 1.3244 %

# %%
sns.pairplot(data)

# %% [markdown]
# # EDA
# ---
# ## Problem Statement
# ### **Does paid advertising clicks cause higher/lower conversion than organic visits?**
#
# ---
#
# In this case,
# *Cause of interest* is under `medium` (or Traffic Type)column,
# - Treatment: paid traffic (`cpc`+`cpm`)
# - Control: `organic` visits through search engines
#
# Thus, we shall focus on these 2 categories (3 values)
#
# > **Note:** The reason why control is ```organic```, instead of ```none```(direct), because we are targeting the *persuadables*, who are people that will convert if targeted by ads, through paid traffic. If it is direct, it means those people are getting into the site through URL typing or bookmarks, which probably means they are **ALREADY PLANNING TO CONVERT**, thus we call them the *sure things*.
# ---
#
# *Outcome* is under `converted` column,
# - 1 means converted
# - 0 means not converted
#
#
#
# ---
# > **Note:**  This analysis treats Google Analytics clickstream data as a **general observational study** where *treatment* (paid traffic) occurs naturally via user ad interactions
#
# ----

# %% [markdown]
# ## **GRAPH 1a**: Conversion Rates by Traffic Medium
#
# Looking at the problem statement, it is natural to visualise the impact of traffic source (`medium`) on converted. But why conversion rate? because we need to normalise against the number of traffic. Essentially, we are just doing this:
#
# $$
# \mathbb{E}[\text{converted} \mid \text{medium}]
# $$
#
# ---
#
# ### - Conversion Rate Plot
#
# We use a ***bar plot*** to visualise the **expected conversion rate given traffic medium**:
#
# Since `converted` is a binary variable (0 = no conversion, 1 = conversion), the mean value within each group represents the **proportion of users who converted**.
#
# ### - Statistical Significance?
#
# Then, we do a chi-sq test to see if there is truly any statistical significance in difference in conversion rate, for the paid(`cpc`+`cpm`) vs orgainic.

# %%
# Conversion rates by medium, eg. out of organic traffic, how many converted.
ax = sns.barplot(data=data, x='medium', y='converted', estimator=lambda x: sum(x)/len(x)*100)
ax.set(title="Conversion Rate by Traffic Type", ylabel="Conversion %")

# run some tests to see if there is a statistically significant difference between paid and organic traffic in terms of conversion
from scipy.stats import chi2_contingency
organic = data[data['medium']=='organic']['converted']
paid = data[(data['medium'] == 'cpc') | (data['medium'] == 'cpm')]['converted']
contingency_table = [
    [sum(paid), len(paid) - sum(paid)],         # paid: converted, not converted
    [sum(organic), len(organic) - sum(organic)]  # organic: converted, not converted
]
print("Contingency Table:")
print(contingency_table)
# Run chi-square test
chi2, pval, dof, expected = chi2_contingency(contingency_table)

# display pvalue on plot
ax.text(0.5, ax.get_ylim()[1] * 0.9, f'paid vs unpaid p-value: {pval:.4f}', ha='center')

plt.show()
# Conclusion: THERE IS A SIGNIFICANT DIFFERENCE BETWEEN PAID AND ORGANIC TRAFFIC IN TERMS OF CONVERSION RATES
# Out:
# Contingency Table:
# [[242, 10775], [1226, 132575]]

# %% [markdown]
# ## Insights from Graph 1:
# - There is statistical significance in the difference btwn paid and organic traffics, as seen from the p-value.
#
# - As suspected from the previous markdown, `(none)` types have a high conversion rates as they are categorised under *sure things*, and has a lower variance compared to paid (`cpc` + `cpm`). They are steady and probably is going to purchase.
#
# - Nobody likes referral and affiliate links
#
# - Paid have a significantly larger variance than most other traffic types
#
# - `(not set)` has a humongus variance, this value of traffic type may not be useful
# ---

# %% [markdown]
# ## **GRAPH 1b**: Converted No. by Traffic Medium
#
# The natural follow up to the above graph is: Even if I know which `medium` is more likely to convert, who are my biggest pile of income? I just want the absolute numbers.

# %%
# Just to check who are the ones who converted the most
sns.barplot(x='medium', y='converted', data=data, estimator=np.count_nonzero, ci=None)
# Out:
# C:\Users\neyma\AppData\Local\Temp\ipykernel_19296\2506356975.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='medium', y='converted', data=data, estimator=np.count_nonzero, ci=None)
# <Axes: xlabel='medium', ylabel='converted'>

# %% [markdown]
# ## Insights from Graph 1b:
#
# - Again, `(none)` types have a high converted numbers as they are categorised under *sure things*.
#
# - Organic searches have much more converted numbers, but as we know, the proportion in Graph 1a tells a better story. We are simply looking at absolute numbers in 1b
# ---

# %% [markdown]
# ## **GRAPH 2a + 2b**: Relationship between Device Type and Traffic Type (`medium`) + Device Type and Conversion
#
# We want to check if there are any potential biases in the device type and (traffic type or conversion). This could help us in analysing & building the causal graph down the road.
#
# ### - 100% Stacked Bar Plot
# This normalises each traffic type/ `medium`, allows us to see the proportions of devices rather than the absolute numbers.

# %%
ct = pd.crosstab(data['medium'], data['deviceCategory'])

# normalisation so that we can see proportions rather than absolute numbers
ct_norm = ct.div(ct.sum(axis=1), axis=0)

# Plot the 100% stacked bar chart
ax = ct_norm.plot(kind='bar', stacked=True, figsize=(10,6))

ax.set_ylabel('Proportion')
ax.set_title('Device Category Distribution by Medium')
plt.xticks(rotation=45)
plt.legend(title='Device Category')
plt.tight_layout()
plt.show()

# %%
ct1 = pd.crosstab(data['converted'], data['deviceCategory'])
# normalisation so that we can see proportions rather than absolute numbers
ct1_norm = ct1.div(ct1.sum(axis=1), axis=0)

# Plot the 100% stacked bar chart
ax1 = ct1_norm.plot(kind='bar', stacked=True, figsize=(10,6))

ax1.set_ylabel('Proportion')
ax1.set_title('Device Category Distribution by Conversion')
plt.legend(title='Device Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights from Graph 2a + 2b:
# - Biggest surprise are affiliate, cpc and referral. `affiliate` & `referral` has much less mobile+tablet device traffic, where `cpc` has SO MUCH MORE mobile+tablet traffic.
#
# - Logically speaking, `cpc` has so much more mobile+tablet traffic is probably due to the nature of device.
#
# <div align="center">
# Mobile device usage → Touch-based interaction → More engagement → More ad clicks
# </div>
#
# - Thus, `deviceCategory` should be a cause of *treatment* (`medium`), not the other way round. Helps us in our DAG causual diagram later.
#
# - Similarly, people tend to purchase big ticket items on desktops LOL, which is shown in this dataset as well.
# ---

# %% [markdown]
# ## **GRAPH 3a + 3b**: Relationship between Countries and Visits + Countries and Conversion
#
# - 3a shows us countries with the biggest potential, as they are the ones visiting our website the most.
#
# On the other hand,
# - 3b shows us who are our biggest customers, purchasing most of our products.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot 3a: Top 10 countries by visits
top_countries = data['country'].value_counts().head(10).index
sns.countplot(data=data[data['country'].isin(top_countries)],
              x='country',
              order=top_countries,
              ax=axes[0])
axes[0].set_title("Top 10 Countries by Visits")
axes[0].set_ylabel("Visit Count")
axes[0].tick_params(axis='x', labelrotation=45, labelsize=9)

# Plot 3b: Top 10 countries by conversions
top_countries_conversion = data[data['converted'] == 1]['country'].value_counts().head(10).index
sns.countplot(data=data[(data['converted'] == 1) & (data['country'].isin(top_countries_conversion))],
              x='country',
              order=top_countries_conversion,
              ax=axes[1],
              color='orange')
axes[1].set_title("Top 10 Countries by Conversion")
axes[1].set_ylabel("Conversion Count")
axes[1].tick_params(axis='x', labelrotation=45, labelsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights from Graph 3a + 3b:
#
# - By far, US has the most visits AND conversion count. This could possibly mean that this dataset is ***extremely skewed towards the US audience***, and we definitely need to ***find a way to eliminate this bias further down the causal inference analysis***.
#
# - India, Vietnam, Turkey, Brazil and Thailand are in the top 10 most visited, but not in the most conversion counts, potentially missing out.
# ---

# %% [markdown]
# ## **GRAPH 4**: Pageviews on medium and conversion

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 7))
sns.boxplot(data=data, x='medium', y='pageviews',ax=axes[0])
data.groupby('medium')['pageviews'].mean()
sns.barplot(data=data, x='medium', y = 'pageviews' , estimator='mean', ax=axes[1])
sns.boxplot(data=data, x='converted', y='pageviews',ax=axes[2])


chi2, pval, dof, expected = chi2_contingency(pd.crosstab(data['converted'], data['pageviews']))

print(f"Chi2: {chi2}, p-value: {pval:.4f}, dof: {dof}")
# Out:
# Chi2: 102530.34334867938, p-value: 0.0000, dof: 184

# %%
# (data.groupby('medium')['bounces']
#      .mean()
#      .plot(kind='bar', title='Bounce Rate by Medium'))

sns.barplot(data=data, x='medium', y='bounces', estimator=np.mean)

plt.ylabel('Bounce Rate')
plt.xlabel('Traffic Medium')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# higher is worse

# %%
# Just a quick correlation analysis to see if i can infer anything for causal relationships
# THIS DOES NOT MEAN CAUSATION = CORRELATION: I AM SIMPLY LOOKING FOR POTENTIAL CAUSAL RELATIONSHIPS, BY INFERING FROM CORRELATION
numeric_data = data.select_dtypes(include=['number'])
corr = numeric_data.corr()
corr.iloc[1:, 1:] # cuz the first data column is 'visitId' which is not relevant for correlation analysis
# Out:
#             pageviews  timeOnSite   bounces   revenue  converted
# pageviews    1.000000    0.642901 -0.401598  0.162945   0.403406
# timeOnSite   0.642901    1.000000       NaN  0.110638   0.273990
# bounces     -0.401598         NaN  1.000000 -0.033716  -0.115091
# revenue      0.162945    0.110638 -0.033716  1.000000   0.292951
# converted    0.403406    0.273990 -0.115091  0.292951   1.000000

# %%
sns.heatmap(data.corr(numeric_only=True), cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Casual DAG

# %%
plt.figure(figsize=(12, 8))

# Initialize graph
G = nx.DiGraph()

# Add nodes with type classification
confounders = ['DeviceType', 'Country']
treatment = ['Treatment']
mediators = ['PageViews', 'TimeOnSite', 'Bounce']
outcome = ['Conversion']
other = ['Campaign']

# Add edges
edges = [
    ('DeviceType', 'Treatment'),
    ('DeviceType', 'Conversion'),
    ('Country', 'Treatment'),
    ('Treatment', 'PageViews'),
    ('Treatment', 'TimeOnSite'), 
    ('Treatment', 'Bounce'),
    ('DeviceType', 'PageViews'),
    ('DeviceType', 'TimeOnSite'),
    ('DeviceType', 'Bounce'),
    ('Country', 'PageViews'),
    ('Country', 'TimeOnSite'),
    ('PageViews', 'Conversion'),
    ('TimeOnSite', 'Conversion'),
    ('TimeOnSite', 'PageViews'),
    ('Bounce', 'Conversion'),
    ('Country', 'Conversion'),
    ('Campaign', 'Conversion')
]

G.add_edges_from(edges)

# Improved layout with more spacing
pos = {
    'DeviceType': (0, 1.5),
    'Country': (0, -1.5),
    'Treatment': (2, 0),
    'PageViews': (6, 1.5),
    'TimeOnSite': (6, 0),
    'Bounce': (6, -1.5),
    'Conversion': (9, 0),
    'Campaign': (6, -3)
}

# Draw nodes with transparency
nx.draw_networkx_nodes(G, pos, node_size=3000,
                      nodelist=confounders, node_color='#FFD700', alpha=0.7)  # Semi-transparent
nx.draw_networkx_nodes(G, pos, node_size=3000,
                      nodelist=treatment, node_color='#FF6347', alpha=0.7)
nx.draw_networkx_nodes(G, pos, node_size=3000,
                      nodelist=mediators, node_color='#20B2AA', alpha=0.7)
nx.draw_networkx_nodes(G, pos, node_size=3000,
                      nodelist=outcome, node_color='#9370DB', alpha=0.7)
nx.draw_networkx_nodes(G, pos, node_size=3000,
                      nodelist=other, node_color='#778899', alpha=0.7)

# Draw edges with visible arrowheads
nx.draw_networkx_edges(
    G, pos, 
    edge_color='gray',
    arrows=True,
    arrowsize=25,  # Larger arrowheads
    arrowstyle='->',  # Solid arrow style
    width=2,
    node_size=3000,  # Match node size
    alpha=0.8,
    min_source_margin=20,  # Add space before arrows
    min_target_margin=20   # Add space after arrows
)

# Labels with white background for readability
label_options = {"ec": "white", "fc": "white", "alpha": 0.7}
nx.draw_networkx_labels(G, pos, font_size=12, font_weight='bold', bbox=label_options)

# Legend
legend_elements = [
    plt.Line2D([0], [0], marker='o', color='w', label='Confounders',
              markerfacecolor='#FFD700', markersize=15, alpha=0.7),
    plt.Line2D([0], [0], marker='o', color='w', label='Treatment',
              markerfacecolor='#FF6347', markersize=15, alpha=0.7),
    plt.Line2D([0], [0], marker='o', color='w', label='Mediators',
              markerfacecolor='#20B2AA', markersize=15, alpha=0.7),
    plt.Line2D([0], [0], marker='o', color='w', label='Outcome',
              markerfacecolor='#9370DB', markersize=15, alpha=0.7),
    plt.Line2D([0], [0], marker='o', color='w', label='Other',
              markerfacecolor='#778899', markersize=15, alpha=0.7)
]

plt.legend(handles=legend_elements, loc='upper right', 
          bbox_to_anchor=(1.25, 1), fontsize=10)

plt.title("Causal DAG: Paid vs Organic Traffic Analysis", 
         fontsize=14, pad=20)
plt.axis('off')
plt.tight_layout()

# # Save with high DPI
# plt.savefig('causal_dag.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# We now want to block the backdoor paths, ie. condition on certain variables so that we can prevent confounding bias, isolating the TRUE effect of the treatment.
#
# However, do note that we should not just block every variable that is not directly casual, because this can lead to Berkson's paradox. Just block the right number of variables.
#
# ---
#
# ### Variables to Condition On (Block)
#
# - **DeviceType**
# - **Country**
#
# These variables are **common causes (forks)** of both the treatment and the outcome. Conditioning on them blocks backdoor paths that could confound the treatment effect.
#
# ---
#
# ### Variables Not to Condition On
#
# - **Campaign**
#
# This variable does **not affect the causal relationship** between treatment and outcome in our graph and can be safely left out.
#
# - **The 3 Mediators** (variables on the causal path from treatment to outcome)
#     - PageViews
#     - TimeOnSite
#     - Bounce
#
# **Do not condition on mediators**, as blocking them would block part of the causal effect we want to measure.
#
# ---
#
# ### Summary
#
# | Variable Type | Examples       | Should Condition On? | Reason                                    |
# |---------------|----------------|---------------------|-------------------------------------------|
# | Confounders   | DeviceType, Country | ✅ Yes              | Block backdoor paths (common causes)      |
# | Treatment-irrelevant | Campaign       | ❌ No               | No impact on causal path                   |
# | Mediators     | PageViews, TimeOnSite (example) | ❌ No               | Blocking would block causal effect itself |
#
# ---

# %% [markdown]
# After conditioning on the confounders, we can now estimate the **causal effect of paid traffic on conversion** using statistical methods like regression analysis or propensity score matching.
# Average treatment effect (ATE) can be estimated by comparing the average conversion rates between the treatment and control groups after conditioning on the confounders.
#
# ---
# The code below is simply narrowing down the dataset:
# 1. filtering the dataset to only include `cpc`, `cpm`, and `organic` traffic types
# 2. binary treatment of paid traffic or not
# 2. creating indicator columns for `deviceCategory` and `country`

# %%
# Narrow down the rows to look at now.
values_to_concentrate = ['organic', 'cpc', 'cpm']
dfnew = data[data['medium'].isin(values_to_concentrate)].copy() # so that i dont edit the data dataframe

# Make the treatment 'is paid' a binary
dfnew['is paid'] = (dfnew['medium'].isin(['cpc','cpm'])).astype(int)

# Now make the categorial data into indicator variables, so that we can parse through ML models
dfnew = pd.get_dummies(dfnew, columns=['deviceCategory', 'country'], drop_first=True,dtype=int) # drop the first to reduc no of variables
pd.crosstab(dfnew['is paid'],dfnew['converted']) # quick confusion matrix
# Out:
# converted       0     1
# is paid
# 0          132575  1226
# 1           10775   242

# %%
dfnew.shape
# took out about 350,000 rows
# Out:
# (144818, 208)

# %% [markdown]
# # Model 1: Logistic Regression
# We first estimate the treatment effect using a logistic regression model that predicts conversion probability based on treatment status and covariates:
# $$\mathbb{P}(\text{converted}=1)=logit^{−1}(β_0 + β_1⋅is paid+β_2⋅country+β_3⋅device)$$
#
# This approach estimates the **average marginal effect** (AME) by comparing conversion between paid and organic traffic users who have the same device category and country. The marginal effect of the treatment variable (`is paid`) gives us the average change in conversion probability when users switch from organic to paid traffic, holding all other covariates constant.
# The key assumption is that conditional on device and country, treatment assignment is independent of potential outcomes - meaning there are no unmeasured confounders that simultaneously affect both traffic source and conversion rates.

# %%
import statsmodels.api as sm
X = dfnew[['is paid'] +[col for col in dfnew.columns if 'deviceCategory_' in col or 'country_' in col]]
Y = dfnew['converted']
X = sm.add_constant(X)

logmodel = sm.Logit(Y,X)
result = logmodel.fit()
print(result.summary())
# something is wrong, and we debugged it below
# Out:
# C:\Users\neyma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\discrete\discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\neyma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\discrete\discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[40], line 7
#       4 X = sm.add_constant(X)
#       6 logmodel = sm.Logit(Y,X)
# ----> 7 result = logmodel.fit()
#       8 print(result.summary())
#       9 # something is wrong, and we debugged it below
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\discrete\discrete_model.py:2601, in Logit.fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    2598 @Appender(DiscreteModel.fit.__doc__)
#    2599 def fit(self, start_params=None, method='newton', maxiter=35,
#    2600         full_output=1, disp=1, callback=None, **kwargs):
# -> 2601     bnryfit = super().fit(start_params=start_params,
#    2602                           method=method,
#    2603                           maxiter=maxiter,
#    2604                           full_output=full_output,
#    2605                           disp=disp,
#    2606                           callback=callback,
#    2607                           **kwargs)
#    2609     discretefit = LogitResults(self, bnryfit)
#    2610     return BinaryResultsWrapper(discretefit)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\discrete\discrete_model.py:243, in DiscreteModel.fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     240 else:
#     241     pass  # TODO: make a function factory to have multiple call-backs
# --> 243 mlefit = super().fit(start_params=start_params,
#     244                      method=method,
#     245                      maxiter=maxiter,
#     246                      full_output=full_output,
#     247                      disp=disp,
#     248                      callback=callback,
#     249                      **kwargs)
#     251 return mlefit
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:582, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     580     Hinv = cov_params_func(self, xopt, retvals)
#     581 elif method == 'newton' and full_output:
# --> 582     Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     583 elif not skip_hessian:
#     584     H = -1 * self.hessian(xopt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\linalg\_linalg.py:609, in inv(a)
#     606 signature = 'D->D' if isComplexType(t) else 'd->d'
#     607 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     608               over='ignore', divide='ignore', under='ignore'):
# --> 609     ainv = _umath_linalg.inv(a, signature=signature)
#     610 return wrap(ainv.astype(result_t, copy=False))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\linalg\_linalg.py:104, in _raise_linalgerror_singular(err, flag)
#     103 def _raise_linalgerror_singular(err, flag):
# --> 104     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %% [markdown]
# ## Problem with Data
# Singular matrix error suggests that the data is not suitable for certain statistical methods, likely due to multicollinearity or insufficient variation in the data. We can see why the data is not suitable in the cell below.

# %%
# singular matrix, meaning that there is a near perfect linear relationship with one or more of the variables
for col in X.columns:
    print(f"\n--- {col} ---")
    print(pd.crosstab(X[col], Y))
# Out:
# --- const ---
# converted       0     1
# const
# 1.0        143350  1468
#
# --- is paid ---
# converted       0     1
# is paid
# 0          132575  1226
# 1           10775   242
#
# --- deviceCategory_mobile ---
# converted                  0     1
# deviceCategory_mobile
# 0                      98157  1271
# 1                      45193   197
#
# --- deviceCategory_tablet ---
# converted                   0     1
# deviceCategory_tablet
# 0                      136529  1431
# 1                        6821    37
#
# --- country_Afghanistan ---
# converted                 0     1
# country_Afghanistan
# 0                    143338  1468
# 1                        12     0
#
# --- country_Albania ---
# converted             0     1
# country_Albania
# 0                143316  1468
# 1                    34     0
#
# --- country_Algeria ---
# converted             0     1
# country_Algeria
# 0                143319  1468
# 1                    31     0
#
# --- country_Andorra ---
# converted             0     1
# country_Andorra
# 0                143349  1468
# 1                     1     0
#
# --- country_Angola ---
# converted            0     1
# country_Angola
# 0               143347  1468
# 1                    3     0
#
# --- country_Antigua & Barbuda ---
# converted                       0     1
# country_Antigua & Barbuda
# 0                          143349  1468
# 1                               1     0
#
# --- country_Argentina ---
# converted               0     1
# country_Argentina
# 0                  142644  1467
# 1                     706     1
#
# --- country_Armenia ---
# converted             0     1
# country_Armenia
# 0                143345  1468
# 1                     5     0
#
# --- country_Aruba ---
# converted           0     1
# country_Aruba
# 0              143342  1468
# 1                   8     0
#
# --- country_Australia ---
# converted               0     1
# country_Australia
# 0                  140195  1467
# 1                    3155     1
#
# --- country_Austria ---
# converted             0     1
# country_Austria
# 0                142759  1468
# 1                   591     0
#
# --- country_Azerbaijan ---
# converted                0     1
# country_Azerbaijan
# 0                   143344  1468
# 1                        6     0
#
# --- country_Bahamas ---
# converted             0     1
# country_Bahamas
# 0                143345  1468
# 1                     5     0
#
# --- country_Bahrain ---
# converted             0     1
# country_Bahrain
# 0                143339  1468
# 1                    11     0
#
# --- country_Bangladesh ---
# converted                0     1
# country_Bangladesh
# 0                   143053  1468
# 1                      297     0
#
# --- country_Barbados ---
# converted              0     1
# country_Barbados
# 0                 143340  1468
# 1                     10     0
#
# --- country_Belarus ---
# converted             0     1
# country_Belarus
# 0                143264  1468
# 1                    86     0
#
# --- country_Belgium ---
# converted             0     1
# country_Belgium
# 0                142431  1467
# 1                   919     1
#
# --- country_Belize ---
# converted            0     1
# country_Belize
# 0               143349  1468
# 1                    1     0
#
# --- country_Benin ---
# converted           0     1
# country_Benin
# 0              143347  1468
# 1                   3     0
#
# --- country_Bermuda ---
# converted             0     1
# country_Bermuda
# 0                143333  1468
# 1                    17     0
#
# --- country_Bhutan ---
# converted            0     1
# country_Bhutan
# 0               143349  1468
# 1                    1     0
#
# --- country_Bolivia ---
# converted             0     1
# country_Bolivia
# 0                143304  1468
# 1                    46     0
#
# --- country_Bosnia & Herzegovina ---
# converted                          0     1
# country_Bosnia & Herzegovina
# 0                             143259  1468
# 1                                 91     0
#
# --- country_Botswana ---
# converted              0     1
# country_Botswana
# 0                 143349  1468
# 1                      1     0
#
# --- country_Brazil ---
# converted            0     1
# country_Brazil
# 0               141808  1465
# 1                 1542     3
#
# --- country_British Virgin Islands ---
# converted                            0     1
# country_British Virgin Islands
# 0                               143349  1468
# 1                                    1     0
#
# --- country_Brunei ---
# converted            0     1
# country_Brunei
# 0               143343  1468
# 1                    7     0
#
# --- country_Bulgaria ---
# converted              0     1
# country_Bulgaria
# 0                 143060  1468
# 1                    290     0
#
# --- country_Burkina Faso ---
# converted                  0     1
# country_Burkina Faso
# 0                     143348  1468
# 1                          2     0
#
# --- country_Cambodia ---
# converted              0     1
# country_Cambodia
# 0                 143321  1468
# 1                     29     0
#
# --- country_Cameroon ---
# converted              0     1
# country_Cameroon
# 0                 143346  1468
# 1                      4     0
#
# --- country_Canada ---
# converted            0     1
# country_Canada
# 0               137967  1437
# 1                 5383    31
#
# --- country_Cape Verde ---
# converted                0     1
# country_Cape Verde
# 0                   143349  1468
# 1                        1     0
#
# --- country_Cayman Islands ---
# converted                    0     1
# country_Cayman Islands
# 0                       143347  1468
# 1                            3     0
#
# --- country_Chile ---
# converted           0     1
# country_Chile
# 0              143034  1467
# 1                 316     1
#
# --- country_China ---
# converted           0     1
# country_China
# 0              142069  1467
# 1                1281     1
#
# --- country_Colombia ---
# converted              0     1
# country_Colombia
# 0                 142517  1464
# 1                    833     4
#
# --- country_Congo - Brazzaville ---
# converted                         0     1
# country_Congo - Brazzaville
# 0                            143349  1468
# 1                                 1     0
#
# --- country_Congo - Kinshasa ---
# converted                      0     1
# country_Congo - Kinshasa
# 0                         143349  1468
# 1                              1     0
#
# --- country_Cook Islands ---
# converted                  0     1
# country_Cook Islands
# 0                     143348  1468
# 1                          2     0
#
# --- country_Costa Rica ---
# converted                0     1
# country_Costa Rica
# 0                   143272  1468
# 1                       78     0
#
# --- country_Croatia ---
# converted             0     1
# country_Croatia
# 0                143046  1468
# 1                   304     0
#
# --- country_Curaçao ---
# converted             0     1
# country_Curaçao
# 0                143342  1467
# 1                     8     1
#
# --- country_Cyprus ---
# converted            0     1
# country_Cyprus
# 0               143252  1468
# 1                   98     0
#
# --- country_Czechia ---
# converted             0     1
# country_Czechia
# 0                142508  1468
# 1                   842     0
#
# --- country_Côte d’Ivoire ---
# converted                   0     1
# country_Côte d’Ivoire
# 0                      143338  1468
# 1                          12     0
#
# --- country_Denmark ---
# converted             0     1
# country_Denmark
# 0                142610  1467
# 1                   740     1
#
# --- country_Djibouti ---
# converted              0     1
# country_Djibouti
# 0                 143349  1468
# 1                      1     0
#
# --- country_Dominican Republic ---
# converted                        0     1
# country_Dominican Republic
# 0                           143250  1468
# 1                              100     0
#
# --- country_Ecuador ---
# converted             0     1
# country_Ecuador
# 0                143230  1467
# 1                   120     1
#
# --- country_Egypt ---
# converted           0     1
# country_Egypt
# 0              143173  1468
# 1                 177     0
#
# --- country_El Salvador ---
# converted                 0     1
# country_El Salvador
# 0                    143256  1468
# 1                        94     0
#
# --- country_Eritrea ---
# converted             0     1
# country_Eritrea
# 0                143349  1468
# 1                     1     0
#
# --- country_Estonia ---
# converted             0     1
# country_Estonia
# 0                143224  1468
# 1                   126     0
#
# --- country_Ethiopia ---
# converted              0     1
# country_Ethiopia
# 0                 143330  1468
# 1                     20     0
#
# --- country_Faroe Islands ---
# converted                   0     1
# country_Faroe Islands
# 0                      143347  1468
# 1                           3     0
#
# --- country_Fiji ---
# converted          0     1
# country_Fiji
# 0             143347  1468
# 1                  3     0
#
# --- country_Finland ---
# converted             0     1
# country_Finland
# 0                143334  1468
# 1                    16     0
#
# --- country_France ---
# converted            0     1
# country_France
# 0               140329  1468
# 1                 3021     0
#
# --- country_French Guiana ---
# converted                   0     1
# country_French Guiana
# 0                      143346  1468
# 1                           4     0
#
# --- country_French Polynesia ---
# converted                      0     1
# country_French Polynesia
# 0                         143342  1468
# 1                              8     0
#
# --- country_Gabon ---
# converted           0     1
# country_Gabon
# 0              143347  1468
# 1                   3     0
#
# --- country_Gambia ---
# converted            0     1
# country_Gambia
# 0               143348  1468
# 1                    2     0
#
# --- country_Georgia ---
# converted             0     1
# country_Georgia
# 0                143250  1468
# 1                   100     0
#
# --- country_Germany ---
# converted             0     1
# country_Germany
# 0                139367  1467
# 1                  3983     1
#
# --- country_Ghana ---
# converted           0     1
# country_Ghana
# 0              143301  1468
# 1                  49     0
#
# --- country_Gibraltar ---
# converted               0     1
# country_Gibraltar
# 0                  143349  1468
# 1                       1     0
#
# --- country_Greece ---
# converted            0     1
# country_Greece
# 0               142698  1468
# 1                  652     0
#
# --- country_Greenland ---
# converted               0     1
# country_Greenland
# 0                  143349  1468
# 1                       1     0
#
# --- country_Grenada ---
# converted             0     1
# country_Grenada
# 0                143345  1468
# 1                     5     0
#
# --- country_Guam ---
# converted          0     1
# country_Guam
# 0             143340  1468
# 1                 10     0
#
# --- country_Guatemala ---
# converted               0     1
# country_Guatemala
# 0                  143337  1468
# 1                      13     0
#
# --- country_Guernsey ---
# converted              0     1
# country_Guernsey
# 0                 143345  1468
# 1                      5     0
#
# --- country_Guinea ---
# converted            0     1
# country_Guinea
# 0               143349  1468
# 1                    1     0
#
# --- country_Guyana ---
# converted            0     1
# country_Guyana
# 0               143348  1468
# 1                    2     0
#
# --- country_Honduras ---
# converted              0     1
# country_Honduras
# 0                 143339  1468
# 1                     11     0
#
# --- country_Hong Kong ---
# converted               0     1
# country_Hong Kong
# 0                  142416  1465
# 1                     934     3
#
# --- country_Hungary ---
# converted             0     1
# country_Hungary
# 0                142968  1468
# 1                   382     0
#
# --- country_Iceland ---
# converted             0     1
# country_Iceland
# 0                143344  1468
# 1                     6     0
#
# --- country_India ---
# converted           0     1
# country_India
# 0              133921  1468
# 1                9429     0
#
# --- country_Indonesia ---
# converted               0     1
# country_Indonesia
# 0                  142207  1463
# 1                    1143     5
#
# --- country_Iran ---
# converted          0     1
# country_Iran
# 0             143349  1468
# 1                  1     0
#
# --- country_Iraq ---
# converted          0     1
# country_Iraq
# 0             143303  1468
# 1                 47     0
#
# --- country_Ireland ---
# converted             0     1
# country_Ireland
# 0                142002  1468
# 1                  1348     0
#
# --- country_Isle of Man ---
# converted                 0     1
# country_Isle of Man
# 0                    143349  1468
# 1                         1     0
#
# --- country_Israel ---
# converted            0     1
# country_Israel
# 0               142717  1468
# 1                  633     0
#
# --- country_Italy ---
# converted           0     1
# country_Italy
# 0              140971  1468
# 1                2379     0
#
# --- country_Jamaica ---
# converted             0     1
# country_Jamaica
# 0                143339  1468
# 1                    11     0
#
# --- country_Japan ---
# converted           0     1
# country_Japan
# 0              140881  1463
# 1                2469     5
#
# --- country_Jersey ---
# converted            0     1
# country_Jersey
# 0               143342  1468
# 1                    8     0
#
# --- country_Jordan ---
# converted            0     1
# country_Jordan
# 0               143261  1468
# 1                   89     0
#
# --- country_Kazakhstan ---
# converted                0     1
# country_Kazakhstan
# 0                   143291  1467
# 1                       59     1
#
# --- country_Kenya ---
# converted           0     1
# country_Kenya
# 0              143269  1468
# 1                  81     0
#
# --- country_Kosovo ---
# converted            0     1
# country_Kosovo
# 0               143328  1468
# 1                   22     0
#
# --- country_Kuwait ---
# converted            0     1
# country_Kuwait
# 0               143321  1468
# 1                   29     0
#
# --- country_Kyrgyzstan ---
# converted                0     1
# country_Kyrgyzstan
# 0                   143347  1468
# 1                        3     0
#
# --- country_Laos ---
# converted          0     1
# country_Laos
# 0             143340  1468
# 1                 10     0
#
# --- country_Latvia ---
# converted            0     1
# country_Latvia
# 0               143222  1468
# 1                  128     0
#
# --- country_Lebanon ---
# converted             0     1
# country_Lebanon
# 0                143344  1468
# 1                     6     0
#
# --- country_Liberia ---
# converted             0     1
# country_Liberia
# 0                143349  1468
# 1                     1     0
#
# --- country_Libya ---
# converted           0     1
# country_Libya
# 0              143349  1468
# 1                   1     0
#
# --- country_Liechtenstein ---
# converted                   0     1
# country_Liechtenstein
# 0                      143348  1468
# 1                           2     0
#
# --- country_Lithuania ---
# converted               0     1
# country_Lithuania
# 0                  143171  1468
# 1                     179     0
#
# --- country_Luxembourg ---
# converted                0     1
# country_Luxembourg
# 0                   143344  1468
# 1                        6     0
#
# --- country_Macau ---
# converted           0     1
# country_Macau
# 0              143328  1468
# 1                  22     0
#
# --- country_Macedonia (FYROM) ---
# converted                       0     1
# country_Macedonia (FYROM)
# 0                          143308  1468
# 1                              42     0
#
# --- country_Madagascar ---
# converted                0     1
# country_Madagascar
# 0                   143346  1468
# 1                        4     0
#
# --- country_Malawi ---
# converted            0     1
# country_Malawi
# 0               143349  1468
# 1                    1     0
#
# --- country_Malaysia ---
# converted              0     1
# country_Malaysia
# 0                 142413  1468
# 1                    937     0
#
# --- country_Maldives ---
# converted              0     1
# country_Maldives
# 0                 143348  1468
# 1                      2     0
#
# --- country_Malta ---
# converted           0     1
# country_Malta
# 0              143336  1468
# 1                  14     0
#
# --- country_Martinique ---
# converted                0     1
# country_Martinique
# 0                   143344  1468
# 1                        6     0
#
# --- country_Mauritania ---
# converted                0     1
# country_Mauritania
# 0                   143348  1468
# 1                        2     0
#
# --- country_Mauritius ---
# converted               0     1
# country_Mauritius
# 0                  143346  1468
# 1                       4     0
#
# --- country_Mayotte ---
# converted             0     1
# country_Mayotte
# 0                143349  1468
# 1                     1     0
#
# --- country_Mexico ---
# converted            0     1
# country_Mexico
# 0               142042  1466
# 1                 1308     2
#
# --- country_Moldova ---
# converted             0     1
# country_Moldova
# 0                143323  1468
# 1                    27     0
#
# --- country_Monaco ---
# converted            0     1
# country_Monaco
# 0               143348  1468
# 1                    2     0
#
# --- country_Mongolia ---
# converted              0     1
# country_Mongolia
# 0                 143346  1468
# 1                      4     0
#
# --- country_Montenegro ---
# converted                0     1
# country_Montenegro
# 0                   143334  1468
# 1                       16     0
#
# --- country_Morocco ---
# converted             0     1
# country_Morocco
# 0                143193  1468
# 1                   157     0
#
# --- country_Mozambique ---
# converted                0     1
# country_Mozambique
# 0                   143347  1468
# 1                        3     0
#
# --- country_Myanmar (Burma) ---
# converted                     0     1
# country_Myanmar (Burma)
# 0                        143332  1468
# 1                            18     0
#
# --- country_Namibia ---
# converted             0     1
# country_Namibia
# 0                143345  1468
# 1                     5     0
#
# --- country_Nepal ---
# converted           0     1
# country_Nepal
# 0              143338  1468
# 1                  12     0
#
# --- country_Netherlands ---
# converted                 0     1
# country_Netherlands
# 0                    141051  1468
# 1                      2299     0
#
# --- country_New Caledonia ---
# converted                   0     1
# country_New Caledonia
# 0                      143348  1468
# 1                           2     0
#
# --- country_New Zealand ---
# converted                 0     1
# country_New Zealand
# 0                    142753  1468
# 1                       597     0
#
# --- country_Nicaragua ---
# converted               0     1
# country_Nicaragua
# 0                  143340  1468
# 1                      10     0
#
# --- country_Niger ---
# converted           0     1
# country_Niger
# 0              143349  1468
# 1                   1     0
#
# --- country_Nigeria ---
# converted             0     1
# country_Nigeria
# 0                143110  1468
# 1                   240     0
#
# --- country_Norfolk Island ---
# converted                    0     1
# country_Norfolk Island
# 0                       143349  1468
# 1                            1     0
#
# --- country_Northern Mariana Islands ---
# converted                              0     1
# country_Northern Mariana Islands
# 0                                 143344  1468
# 1                                      6     0
#
# --- country_Norway ---
# converted            0     1
# country_Norway
# 0               142867  1468
# 1                  483     0
#
# --- country_Oman ---
# converted          0     1
# country_Oman
# 0             143327  1468
# 1                 23     0
#
# --- country_Pakistan ---
# converted              0     1
# country_Pakistan
# 0                 142791  1468
# 1                    559     0
#
# --- country_Palestine ---
# converted               0     1
# country_Palestine
# 0                  143336  1468
# 1                      14     0
#
# --- country_Panama ---
# converted            0     1
# country_Panama
# 0               143281  1467
# 1                   69     1
#
# --- country_Paraguay ---
# converted              0     1
# country_Paraguay
# 0                 143345  1468
# 1                      5     0
#
# --- country_Peru ---
# converted          0     1
# country_Peru
# 0             142774  1467
# 1                576     1
#
# --- country_Philippines ---
# converted                 0     1
# country_Philippines
# 0                    142185  1468
# 1                      1165     0
#
# --- country_Poland ---
# converted            0     1
# country_Poland
# 0               142145  1467
# 1                 1205     1
#
# --- country_Portugal ---
# converted              0     1
# country_Portugal
# 0                 142861  1468
# 1                    489     0
#
# --- country_Puerto Rico ---
# converted                 0     1
# country_Puerto Rico
# 0                    143198  1467
# 1                       152     1
#
# --- country_Qatar ---
# converted           0     1
# country_Qatar
# 0              143288  1468
# 1                  62     0
#
# --- country_Romania ---
# converted             0     1
# country_Romania
# 0                142917  1468
# 1                   433     0
#
# --- country_Russia ---
# converted            0     1
# country_Russia
# 0               142375  1467
# 1                  975     1
#
# --- country_Rwanda ---
# converted            0     1
# country_Rwanda
# 0               143349  1468
# 1                    1     0
#
# --- country_Réunion ---
# converted             0     1
# country_Réunion
# 0                143330  1468
# 1                    20     0
#
# --- country_San Marino ---
# converted                0     1
# country_San Marino
# 0                   143349  1468
# 1                        1     0
#
# --- country_Saudi Arabia ---
# converted                  0     1
# country_Saudi Arabia
# 0                     143039  1466
# 1                        311     2
#
# --- country_Senegal ---
# converted             0     1
# country_Senegal
# 0                143348  1468
# 1                     2     0
#
# --- country_Serbia ---
# converted            0     1
# country_Serbia
# 0               143148  1468
# 1                  202     0
#
# --- country_Seychelles ---
# converted                0     1
# country_Seychelles
# 0                   143349  1468
# 1                        1     0
#
# --- country_Singapore ---
# converted               0     1
# country_Singapore
# 0                  141950  1468
# 1                    1400     0
#
# --- country_Sint Maarten ---
# converted                  0     1
# country_Sint Maarten
# 0                     143348  1468
# 1                          2     0
#
# --- country_Slovakia ---
# converted              0     1
# country_Slovakia
# 0                 142934  1468
# 1                    416     0
#
# --- country_Slovenia ---
# converted              0     1
# country_Slovenia
# 0                 143214  1468
# 1                    136     0
#
# --- country_South Africa ---
# converted                  0     1
# country_South Africa
# 0                     142942  1467
# 1                        408     1
#
# --- country_South Korea ---
# converted                 0     1
# country_South Korea
# 0                    142840  1467
# 1                       510     1
#
# --- country_Spain ---
# converted           0     1
# country_Spain
# 0              141231  1468
# 1                2119     0
#
# --- country_Sri Lanka ---
# converted               0     1
# country_Sri Lanka
# 0                  143018  1468
# 1                     332     0
#
# --- country_St. Barthélemy ---
# converted                    0     1
# country_St. Barthélemy
# 0                       143349  1468
# 1                            1     0
#
# --- country_St. Kitts & Nevis ---
# converted                       0     1
# country_St. Kitts & Nevis
# 0                          143348  1468
# 1                               2     0
#
# --- country_St. Lucia ---
# converted               0     1
# country_St. Lucia
# 0                  143345  1467
# 1                       5     1
#
# --- country_St. Vincent & Grenadines ---
# converted                              0     1
# country_St. Vincent & Grenadines
# 0                                 143348  1468
# 1                                      2     0
#
# --- country_Sudan ---
# converted           0     1
# country_Sudan
# 0              143347  1468
# 1                   3     0
#
# --- country_Suriname ---
# converted              0     1
# country_Suriname
# 0                 143348  1468
# 1                      2     0
#
# --- country_Sweden ---
# converted            0     1
# country_Sweden
# 0               142154  1468
# 1                 1196     0
#
# --- country_Switzerland ---
# converted                 0     1
# country_Switzerland
# 0                    142442  1468
# 1                       908     0
#
# --- country_Taiwan ---
# converted            0     1
# country_Taiwan
# 0               141720  1464
# 1                 1630     4
#
# --- country_Tanzania ---
# converted              0     1
# country_Tanzania
# 0                 143326  1468
# 1                     24     0
#
# --- country_Thailand ---
# converted              0     1
# country_Thailand
# 0                 142679  1467
# 1                    671     1
#
# --- country_Togo ---
# converted          0     1
# country_Togo
# 0             143346  1468
# 1                  4     0
#
# --- country_Trinidad & Tobago ---
# converted                       0     1
# country_Trinidad & Tobago
# 0                          143338  1468
# 1                              12     0
#
# --- country_Tunisia ---
# converted             0     1
# country_Tunisia
# 0                143328  1468
# 1                    22     0
#
# --- country_Turkey ---
# converted            0     1
# country_Turkey
# 0               142223  1466
# 1                 1127     2
#
# --- country_Turkmenistan ---
# converted                  0     1
# country_Turkmenistan
# 0                     143349  1468
# 1                          1     0
#
# --- country_Turks & Caicos Islands ---
# converted                            0     1
# country_Turks & Caicos Islands
# 0                               143348  1468
# 1                                    2     0
#
# --- country_U.S. Virgin Islands ---
# converted                         0     1
# country_U.S. Virgin Islands
# 0                            143347  1468
# 1                                 3     0
#
# --- country_Uganda ---
# converted            0     1
# country_Uganda
# 0               143330  1468
# 1                   20     0
#
# --- country_Ukraine ---
# converted             0     1
# country_Ukraine
# 0                142782  1467
# 1                   568     1
#
# --- country_United Arab Emirates ---
# converted                          0     1
# country_United Arab Emirates
# 0                             142989  1467
# 1                                361     1
#
# --- country_United Kingdom ---
# converted                    0     1
# country_United Kingdom
# 0                       134296  1467
# 1                         9054     1
#
# --- country_United States ---
# converted                  0     1
# country_United States
# 0                      80470   128
# 1                      62880  1340
#
# --- country_Uruguay ---
# converted             0     1
# country_Uruguay
# 0                143298  1467
# 1                    52     1
#
# --- country_Uzbekistan ---
# converted                0     1
# country_Uzbekistan
# 0                   143343  1468
# 1                        7     0
#
# --- country_Vanuatu ---
# converted             0     1
# country_Vanuatu
# 0                143347  1468
# 1                     3     0
#
# --- country_Venezuela ---
# converted               0     1
# country_Venezuela
# 0                  142995  1426
# 1                     355    42
#
# --- country_Vietnam ---
# converted             0     1
# country_Vietnam
# 0                142709  1468
# 1                   641     0
#
# --- country_Yemen ---
# converted           0     1
# country_Yemen
# 0              143347  1468
# 1                   3     0
#
# --- country_Zambia ---
# converted            0     1
# country_Zambia
# 0               143342  1468
# 1                    8     0
#
# --- country_Zimbabwe ---
# converted              0     1
# country_Zimbabwe
# 0                 143347  1468
# 1                      3     0

# %% [markdown]
# ## Fixing the data
# As we can see, there are **many countries with very few visits, and also very few conversions**. This can cause the logistic regression to fail, because the model is has unpredictable coefficients, most likely having singular predictions, thus the singular matrix error. (quasi-perfect separation)
#
#     Example:
#
#     Country X: 3 visits, 0 conversions → conversion rate = 0%
#     Country Y: 2 visits, 2 conversions → conversion rate = 100%
#
#     The model tries to fit coefficients for these extreme cases, leading to:
#
#     - Huge coefficient values (trying to predict 0% vs 100%)
#     - Unstable estimates (small changes in data drastically change results)
#     - Perfect multicollinearity — one column is a perfect linear combo of others, causing singular matrix errors
#
# ---
#
# To fix this, we only included countries with more than 10 conversions to discard small data.

# %%
# Narrow down the rows to look at now.
values_to_concentrate = ['organic', 'cpc', 'cpm']
dfnew = data[data['medium'].isin(values_to_concentrate)].copy() # so that i dont edit the data dataframe

# Make the treatment 'is paid' a binary
dfnew['is paid'] = (dfnew['medium'].isin(['cpc','cpm'])).astype(int)

# New step: only take the countries with more converted values
country_conversions = data.groupby('country')['converted'].sum()
contries_to_consider = country_conversions[country_conversions>=10].index
print(contries_to_consider)
df_filtered1 = dfnew[dfnew['country'].isin(contries_to_consider)].copy()


df_filtered = pd.get_dummies(df_filtered1, columns=['deviceCategory', 'country'], drop_first=True)
print(df_filtered.columns)
# Out:
# Index(['Australia', 'Canada', 'Japan', 'Mexico', 'Taiwan', 'United States',
#        'Venezuela'],
#       dtype='object', name='country')
# Index(['fullVisitorId', 'visitId', 'medium', 'source', 'campaign', 'city',
#        'pageviews', 'timeOnSite', 'bounces', 'revenue', 'converted', 'is paid',
#        'deviceCategory_mobile', 'deviceCategory_tablet', 'country_Canada',
#        'country_Japan', 'country_Mexico', 'country_Taiwan',
#        'country_United States', 'country_Venezuela'],
#       dtype='object')

# %% [markdown]
# ### Logistic Regression: *Confounder variables + `is paid` against Outcome*
# $$\mathbb{P}(\text{converted} = 1 \mid \text{is paid, deviceCategory, country})$$

# %%
X = df_filtered[['is paid'] +[col for col in df_filtered.columns if 'deviceCategory_' in col or 'country_' in col]]
Y = df_filtered['converted']
X = sm.add_constant(X)

bool_cols = X.select_dtypes(include='bool').columns
X[bool_cols] = X[bool_cols].astype(int)

logmodel = sm.Logit(Y,X)
result = logmodel.fit(maxiter=100)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.085816
#          Iterations 12
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              converted   No. Observations:                78605
# Model:                          Logit   Df Residuals:                    78595
# Method:                           MLE   Df Model:                            9
# Date:                Wed, 16 Jul 2025   Pseudo R-squ.:                 0.05347
# Time:                        12:11:14   Log-Likelihood:                -6745.6
# converged:                       True   LL-Null:                       -7126.6
# Covariance Type:            nonrobust   LLR p-value:                2.960e-158
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -7.7418      1.000     -7.740      0.000      -9.702      -5.781
# is paid                   0.1940      0.072      2.691      0.007       0.053       0.335
# deviceCategory_mobile    -1.2429      0.078    -15.900      0.000      -1.396      -1.090
# deviceCategory_tablet    -1.0017      0.168     -5.961      0.000      -1.331      -0.672
# country_Canada            2.8554      1.016      2.810      0.005       0.863       4.847
# country_Japan             1.8300      1.096      1.670      0.095      -0.318       3.978
# country_Mexico            1.5146      1.225      1.236      0.216      -0.887       3.916
# country_Taiwan            1.9057      1.119      1.704      0.088      -0.287       4.098
# country_United States     4.1889      1.001      4.186      0.000       2.228       6.150
# country_Venezuela         5.7218      1.014      5.645      0.000       3.735       7.708
# =========================================================================================

# %% [markdown]
# # Interpreting the Model 1
#
# ## Model Analysis
# > Note: Since we are simply trying to explain the causal effect, prediction (AUC) and model selection metrics (AIC) or Log-Likelihood is not very useful to for our causal inference model.
#
# | Statistic           | Value         |
# |---------------------|---------------|
# | **Log-Likelihood**  | -6745.6       |
# | **LL-Null**         | -7126.6       |
# | **Likelihood Ratio Test (LLR) p-value** | 2.960 × 10⁻¹⁵⁸ |
#
# This means that this Logistic Regression is *better* than null model, and is *significant*.
#
#
#
# ---
#
# ## Variable analysis
#
# The intercept (`const`) is **−7.7418**, which implies that the **baseline log-odds** of conversion — for a user who is:
# - On **organic traffic**
# - Using a **desktop**
# - From **Australia** (assuming Australia was the dropped category)
#
# is:
#
# $$
# \text{Odds} = e^{-7.7418} \approx 0.00043
# $$
#
# This reflects a **very low baseline probability** of conversion.
#
# ---
#
# ### Interpreting Other Coefficients
#
# Each coefficient represents the **change in log-odds of conversion**, relative to the baseline. (CONSIDER THE PVALUES TOO)
#
#  `is paid` = **0.1940**
# - Being in a **paid medium** (cpc or cpm) increases the log-odds by 0.1940.
# - The odds ratio is:
#
# $$
# e^{0.1940} \approx 1.2139
# $$
#
# → This means paid traffic has **21.4% higher odds** of conversion, *all else being equal*, at a **0.007 p-value**. (ie. could only observe this or more extreme with 0.7% of the time by chance, statistically significant)
#
# ---
#
#  `deviceCategory_mobile` = **−1.2429**
# - Using a **mobile device** decreases log-odds by −1.2429.
# - The odds ratio is:
#
#
# $$e^{-1.2429} \approx 0.2885
# $$
#
# → Mobile users have **about 71% lower odds** of conversion than desktop users, *all else being equal*.
#
# ---
#
# > To interpret any other variable, just apply:
# > $$
# > \text{Odds Ratio} = e^{\text{coefficient}}
# > $$
# > and compare against the baseline category.
# > remember to check the p-values too, as they indicate statistical significance.
#
# ---
#
# However, we are not done yet! We simply checked whether there might be a relationship betweeen `country` + `deviceCategory` against `conversion`.
#
# > ***We have not checked for if it has a relationship with the treatment (`is paid`) as the y, which is the next step.***

# %% [markdown]
# ### Logistic Regression: *Potential Confounder variables against Treatment*
#
# Essentially,
# $$\mathbb{P}(\text{is paid} = 1 \mid \text{deviceCategory, country}) = \frac{1}{1 + e^{-(\beta|_0 + \beta_1 X_1 + \dots + \beta_k X_k)}}$$
#
# This step is to:
# 1. Support our DAG if `deviceCategory` and `country` does associate with treatment (Note that is support and associate, doesn't confirm causal)
# 2. Builds up the foundation for Model 2: PSM

# %%
# this time, y shall be treatment/is paid. We are seeing if devicecat and country affects treatment
X1 = df_filtered[[col for col in df_filtered.columns if 'deviceCategory_' in col or 'country_' in col]]
Y1 = df_filtered['is paid']
X1 = sm.add_constant(X1)

bool_cols = X1.select_dtypes(include='bool').columns
X1[bool_cols] = X1[bool_cols].astype(int)

logmodel1 = sm.Logit(Y1,X1)
result1 = logmodel1.fit(maxiter=100)
print(result1.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.370375
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                is paid   No. Observations:                78605
# Model:                          Logit   Df Residuals:                    78596
# Method:                           MLE   Df Model:                            8
# Date:                Wed, 16 Jul 2025   Pseudo R-squ.:                 0.04723
# Time:                        12:23:01   Log-Likelihood:                -29113.
# converged:                       True   LL-Null:                       -30556.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -5.3435      0.251    -21.303      0.000      -5.835      -4.852
# deviceCategory_mobile     0.1197      0.023      5.271      0.000       0.075       0.164
# deviceCategory_tablet     0.2598      0.047      5.520      0.000       0.168       0.352
# country_Canada            2.1758      0.260      8.383      0.000       1.667       2.684
# country_Japan            -0.0330      0.383     -0.086      0.931      -0.783       0.717
# country_Mexico            1.0218      0.345      2.960      0.003       0.345       1.698
# country_Taiwan            0.6927      0.355      1.952      0.051      -0.003       1.388
# country_United States     3.5998      0.251     14.348      0.000       3.108       4.092
# country_Venezuela         0.0231      0.752      0.031      0.976      -1.451       1.497
# =========================================================================================

# %% [markdown]
# ## Interpreting the results
# Again, very similar to the previous logistic regression, we can interpret the coefficients in a similar way, which I will not repeat the same steps as it is unnecessary. I will only point out the key insights.
#
# ### Insights from the next logistic regression
# United States, Canada and Mexico seems to have the most paid traffic. This could potentially mean that this dataset/ marketing advertisement is mainly done in America!
#
# The difference in magnitudes of coefficients and low p-values shows that `deviceCategory` and several `country` significantly predict the likelihood of receiving paid traffic (`is paid`). This supports our causal graph assumptions.
#
# ---
#
# Thus, we can conclude that the `deviceCategory` and `country` variables are **highly likely confounders**, due to their high association with both treatment and control, but this is if my casual graph/ assumptions holds true.

# %% [markdown]
# ## Getting the Average Marginal Effect (AME)
# Now that we got the models, we should take a look at the average treatment effect. Essentially:
# $$
# \text{AME} = \frac{1}{n}\sum_{i=1}^n \left[ \underbrace{P(Y_i=1|T_i=1,X_i)}_{\text{Probability if treated}} - \underbrace{P(Y_i=1|T_i=0,X_i)}_{\text{Probability if control}} \right]
# $$
# Where:
# - $X_i$ are confounder variables (`deviceCategory`, `country`)
# - $Y_i$ is the outcome (`converted`)
# - $T_i$ is the treatment (`is paid`)
#
# We are trying to see what is the average change in conversion probability if EVERYONE *in our data* switched from organic to paid traffic, after conditioning on the confounders.
#
# ---
#
# > ***AME != ATE***, its iff:
# > 1. When this sample is representative of the population
# > 2. When this regression model is correctly specified
# > 3. When there is no unmeasured confounders
#
# > TLDR, AME is only an estimate for ATE. There are conditions that need to be met for AME = ATE, but many observational studies simply says ATE because they assume those conditions hold

# %%
marginaleff = result.get_margeff()
print(marginaleff.summary())
# Out:
#         Logit Marginal Effects
# =====================================
# Dep. Variable:              converted
# Method:                          dydx
# At:                           overall
# =========================================================================================
#                            dy/dx    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# is paid                   0.0034      0.001      2.685      0.007       0.001       0.006
# deviceCategory_mobile    -0.0219      0.001    -14.818      0.000      -0.025      -0.019
# deviceCategory_tablet    -0.0177      0.003     -5.899      0.000      -0.024      -0.012
# country_Canada            0.0503      0.018      2.803      0.005       0.015       0.086
# country_Japan             0.0323      0.019      1.668      0.095      -0.006       0.070
# country_Mexico            0.0267      0.022      1.236      0.217      -0.016       0.069
# country_Taiwan            0.0336      0.020      1.702      0.089      -0.005       0.072
# country_United States     0.0738      0.018      4.163      0.000       0.039       0.109
# country_Venezuela         0.1009      0.018      5.593      0.000       0.066       0.136
# =========================================================================================

# %% [markdown]
# ## Insights from AME
#
# The dy/dx of `is paid` is 0.0034.
#
# ---
#
# > ## Controlling for *device* and *country*, paid traffic *increases conversion probability by 0.34%* points on average

# %% [markdown]
# ## Model 2: Propensity Score Matching using NN algorithm
# ### a quasi experimental design to get **Average Treatment Effect** (ATE)
#
# ---
#
# Step 1: Calculate propensity score for each row, that would receive this treatment, conditioned on the confounders. (ie. using the previous model to do prediction on every row)
# $$\mathbb{P}(\text{is paid} = 1 \mid \text{deviceCategory, country}) $$
#
# Step 2: Match treated and control units with similar propensity scores using nearest neighbor algorithm
# - For each treated unit (is paid = 1), find the control unit (is paid = 0) with the closest propensity score
# - Use 1:1 matching without replacement to create balanced pairs
# - This creates a "quasi-experimental" design where treatment assignment is approximately random within matched pairs
#
# Step 3: Calculate ATE by comparing outcomes between matched groups
# $$\text{ATE} = \frac{1}{N_{\text{matches}}} \sum_{i=1}^{N_{\text{matches}}} \left[ Y_i^{\text{is paid}} - Y_i^{\text{organic}} \right]$$
#
#
# ---
#
# ### Key Assumption: **Unconfoundedness**
# After conditioning on propensity scores, treatment assignment is independent of potential outcomes:
# $$Y^0, Y^1 \perp T \mid e(X)$$
#
# Where $e(X)$ is the propensity score and $Y^0, Y^1$ are potential outcomes under control and treatment.
#
# In other words, the potential outcomes are independent of your treatment, given your propensity score (how likely you are to recieve treatment/ condition on confounders).
#
# ---
#
# ### Theoretical Understanding
#
# Among users with the same propensity score (same chance to recieve treatment), the chance of treatment will now be theoretically random! VERY IMPORTANT!!
#
# This leads to a quasi-parallel world/ experimental comparison, the difference in whether you convert or not could only be from the treatment! In python:
#
# ```python
# ate = treated_outcomes.mean() - control_outcomes.mean()
# ```
# > This gives us the average difference in conversion probability treated vs. untreated

# %%
from causalml.match import NearestNeighborMatch

# Step 1
# add a column propensity score for the prediciton based on logmodel1
df_filtered['propensity_score'] = result1.predict(X1)


# Step 2
# we match treated + control units with simalr propensity scores
matcher = NearestNeighborMatch(replace=False, ratio=1, random_state=69)
matched_indices = matcher.match(
    data=df_filtered,
    treatment_col='is paid',
    score_cols=['propensity_score']
)

# True or False values per row of matched_indices
treated_mask = matched_indices['is paid'] == 1
control_mask = matched_indices['is paid'] == 0

# each outcome is a column of converted or not, a 0 or 1!!
treated_outcomes = matched_indices.loc[treated_mask, 'converted']
control_outcomes = matched_indices.loc[control_mask, 'converted']

# Step 3 
# calculate ATE
ate = treated_outcomes.mean() - control_outcomes.mean()
print(f"PSM ATE: {ate:.4f}")
print(f"Number of matches: {len(treated_outcomes)}")
# Out:
# PSM ATE: 0.0038
# Number of matches: 10316, 10316
# 360107    0
# 258649    1
# 68643     0
# 394228    1
# 332099    0
# Name: converted, dtype: int64

# %% [markdown]
# ## Interpreting Model 2:
#
# > ## Using Propensity Score Matching, paid traffic **increases conversion probability of 0.38%** than similar organic visits.

# %% [markdown]
# ## Model 3: Inverse Probability Weighting

# %%
# Step 1: Use existing propensity scores from your model
# Make sure you have a 'propensity_score' column in df_filtered
propensity_scores = df_filtered['propensity_score']
treatment = df_filtered['is paid']
outcome = df_filtered['converted']

# Step 2: Calculate IPW weights
weights = np.where(treatment == 1, 
                   1 / propensity_scores,           # Treated: 1/P(T=1|X)
                   1 / (1 - propensity_scores))     # Control: 1/P(T=0|X)

# Step 3: Separate masks for treated and control
treated_mask = treatment == 1
control_mask = treatment == 0

# Step 4: Calculate weighted mean outcomes
treated_weighted_outcome = np.average(outcome[treated_mask], 
                                      weights=weights[treated_mask])

control_weighted_outcome = np.average(outcome[control_mask], 
                                      weights=weights[control_mask])

# Step 5: Compute ATE
ate_ipw = treated_weighted_outcome - control_weighted_outcome

# Step 6: Print results
print(f"IPW ATE: {ate_ipw:.4f}")
print(f"Treated weighted outcome: {treated_weighted_outcome:.4f}")
print(f"Control weighted outcome: {control_weighted_outcome:.4f}")
print(f"Sample size: {len(df_filtered)}")

ipw_results = {
    'ate_ipw': ate_ipw,
    'treated_outcome': treated_weighted_outcome,
    'control_outcome': control_weighted_outcome,
    'weights': weights
}
# Out:
# IPW ATE: 0.0029
# Treated weighted outcome: 0.0205
# Control weighted outcome: 0.0176
# Sample size: 78605
